# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import numpy as np
import pandas as pd
import statistics

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
admission_df = pd.read_csv("Admission_Predict.csv")
admission_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
# 382         383        330          116                  4  5.0   4.5  9.45
# 383         384        312          103                  3  3.5   4.0  8.78
# 384         385        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here
admission_df = admission_df.applymap(lambda x: x.rstrip() if isinstance(x, str) else x)
admission_df

#i dont think it as changed anything

#df_admissions_predict.rename(columns = lambda x: x.strip(), inplace = True)

#admission_df.columns = [col.strip() for col in admission_df.columns]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
# 382         383        330          116                  4  5.0   4.5  9.45
# 383         384        312          103                  3  3.5   4.0  8.78
# 384         385        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here

admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
admission_df.isna().any()

#admission_df.isna().sum()
# Out:
# Serial No.           False
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here

admission_df.set_index("Serial No.",drop=False)
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# Serial No.
# 1                    1        337          118                  4  4.5   4.5
# 2                    2        316          104                  3  3.0   3.5
# 3                    3        322          110                  3  3.5   2.5
# 4                    4        314          103                  2  2.0   3.0
# 5                    5        330          115                  5  4.5   3.0
# ...                ...        ...          ...                ...  ...   ...
# 381                381        324          110                  3  3.5   3.5
# 382                382        325          107                  3  3.0   3.5
# 383                383        330          116                  4  5.0   4.5
# 384                384        312          103                  3  3.5   4.0
# 385                385        333          117                  4  5.0   4.0
#
# ...

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# your code here

#gre_unique = len(admission_df["GRE Score"].unique())
#gre_unique

# %%
#CGPA_unique = len(admission_df["CGPA"].unique())
#CGPA_unique

# %%
#correct:

admission_df.groupby(['GRE Score', 'CGPA']).size()

#ou

#admission_df.groupby(['GRE Score','CGPA']).value_counts()
# Out:
# GRE Score  CGPA
# 290        7.46    1
#            7.56    1
# 293        7.80    1
# 294        7.36    1
#            7.64    1
#                   ..
# 340        9.60    1
#            9.66    1
#            9.74    1
#            9.91    1
#            9.92    1
# Length: 385, dtype: int64

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# your code here

admission_df.index = pd.MultiIndex.from_arrays(admission_df[['GRE Score', 'CGPA']].values.T, names=['GRE Score', 'CGPA'])

admission_df
# Out:
#                 Serial No.  GRE Score  TOEFL Score  University Rating  SOP  \
# GRE Score CGPA
# 337.0     9.65           1        337          118                  4  4.5
# 316.0     8.00           2        316          104                  3  3.0
# 322.0     8.67           3        322          110                  3  3.5
# 314.0     8.21           4        314          103                  2  2.0
# 330.0     9.34           5        330          115                  5  4.5
# ...                    ...        ...          ...                ...  ...
# 324.0     9.04         381        324          110                  3  3.5
# 325.0     9.11         382        325          107                  3  3.0
# 330.0     9.45         383        330          116                  4  5.0
# 312.0     8.78         384        312          103                  3  3.5
# 333.0     9.66         385        333          117                  4  5.0
#
# ...

# %%
admission_df.drop(["GRE Score", "CGPA"], axis=1, inplace=True)
admission_df
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# GRE Score CGPA
# 337.0     9.65           1          118                  4  4.5   4.5
# 316.0     8.00           2          104                  3  3.0   3.5
# 322.0     8.67           3          110                  3  3.5   2.5
# 314.0     8.21           4          103                  2  2.0   3.0
# 330.0     9.34           5          115                  5  4.5   3.0
# ...                    ...          ...                ...  ...   ...
# 324.0     9.04         381          110                  3  3.5   3.5
# 325.0     9.11         382          107                  3  3.0   3.5
# 330.0     9.45         383          116                  4  5.0   4.5
# 312.0     8.78         384          103                  3  3.5   4.0
# 333.0     9.66         385          117                  4  5.0   4.0
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 337.0     9.65         1              0.92
# ...

# %%
admission_df.reset_index(inplace=True)

# %%
admission_df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# 0        337.0  9.65           1          118                  4  4.5   4.5
# 1        316.0  8.00           2          104                  3  3.0   3.5
# 2        322.0  8.67           3          110                  3  3.5   2.5
# 3        314.0  8.21           4          103                  2  2.0   3.0
# 4        330.0  9.34           5          115                  5  4.5   3.0
# ..         ...   ...         ...          ...                ...  ...   ...
# 380      324.0  9.04         381          110                  3  3.5   3.5
# 381      325.0  9.11         382          107                  3  3.0   3.5
# 382      330.0  9.45         383          116                  4  5.0   4.5
# 383      312.0  8.78         384          103                  3  3.5   4.0
# 384      333.0  9.66         385          117                  4  5.0   4.0
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# your code here

def cgpa_research(admission_df):
    return len(admission_df[(admission_df['CGPA'] > 9) & (admission_df['Research'] != 0)])

result = cgpa_research(admission_df)

result
# Out:
# 101

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
def cgpa_sop(admission_df):
    cgpa_sop_rows = admission_df[(admission_df['CGPA'] > 9) & (admission_df['SOP'] < 3.5)]
    
    return cgpa_sop_rows

result2 = cgpa_sop(admission_df)


result2
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# 28       338.0  9.40          29          118                  4  3.0   4.5
# 62       327.0  9.02          63          114                  3  3.0   3.0
# 140      326.0  9.11         141          114                  3  3.0   3.0
# 217      324.0  9.01         218          111                  4  3.0   3.0
# 381      325.0  9.11         382          107                  3  3.0   3.5
#
#      Research  Chance of Admit
# 28          1              0.91
# 62          0              0.61
# 140         1              0.83
# 217         1              0.82
# 381         1              0.84

# %%
admission_df["Chance of Admit "].mean()
# Out:
# 0.7239220779220779

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    
    stan_col = (col - np.mean(col) / np.std(col))
    
    return stan_col
    
    # your code here

# %%
admission_df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# 0        337.0  9.65           1          118                  4  4.5   4.5
# 1        316.0  8.00           2          104                  3  3.0   3.5
# 2        322.0  8.67           3          110                  3  3.5   2.5
# 3        314.0  8.21           4          103                  2  2.0   3.0
# 4        330.0  9.34           5          115                  5  4.5   3.0
# ..         ...   ...         ...          ...                ...  ...   ...
# 380      324.0  9.04         381          110                  3  3.5   3.5
# 381      325.0  9.11         382          107                  3  3.0   3.5
# 382      330.0  9.45         383          116                  4  5.0   4.5
# 383      312.0  8.78         384          103                  3  3.5   4.0
# 384      333.0  9.66         385          117                  4  5.0   4.0
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here

admission_df["CGPA_std"] = standardize(admission_df["CGPA"])
admission_df["GRE_std"] = standardize(admission_df["GRE Score"])
admission_df["LOR_std"] = standardize(admission_df["LOR "])

admission_df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# 0        337.0  9.65           1          118                  4  4.5   4.5
# 1        316.0  8.00           2          104                  3  3.0   3.5
# 2        322.0  8.67           3          110                  3  3.5   2.5
# 3        314.0  8.21           4          103                  2  2.0   3.0
# 4        330.0  9.34           5          115                  5  4.5   3.0
# ..         ...   ...         ...          ...                ...  ...   ...
# 380      324.0  9.04         381          110                  3  3.5   3.5
# 381      325.0  9.11         382          107                  3  3.0   3.5
# 382      330.0  9.45         383          116                  4  5.0   4.5
# 383      312.0  8.78         384          103                  3  3.5   4.0
# 384      333.0  9.66         385          117                  4  5.0   4.0
#
# ...

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ["CGPA_std", "GRE_std", "LOR_std"]

decision_choice = choices(std_columns, k=admission_df.shape[0])

# %%
admission_df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# 0        337.0  9.65           1          118                  4  4.5   4.5
# 1        316.0  8.00           2          104                  3  3.0   3.5
# 2        322.0  8.67           3          110                  3  3.5   2.5
# 3        314.0  8.21           4          103                  2  2.0   3.0
# 4        330.0  9.34           5          115                  5  4.5   3.0
# ..         ...   ...         ...          ...                ...  ...   ...
# 380      324.0  9.04         381          110                  3  3.5   3.5
# 381      325.0  9.11         382          107                  3  3.0   3.5
# 382      330.0  9.45         383          116                  4  5.0   4.5
# 383      312.0  8.78         384          103                  3  3.5   4.0
# 384      333.0  9.66         385          117                  4  5.0   4.0
#
# ...

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here
admission_df["decision_choice"] = choices(std_columns, k=admission_df.shape[0])

def lookup_decision(row):
    return row[row["decision_choice"]]

admission_df["deciding_column"] = admission_df.apply(lookup_decision, axis=1)

admission_df.drop(columns=["decision_choice"], inplace=True)

admission_df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# 0        337.0  9.65           1          118                  4  4.5   4.5
# 1        316.0  8.00           2          104                  3  3.0   3.5
# 2        322.0  8.67           3          110                  3  3.5   2.5
# 3        314.0  8.21           4          103                  2  2.0   3.0
# 4        330.0  9.34           5          115                  5  4.5   3.0
# ..         ...   ...         ...          ...                ...  ...   ...
# 380      324.0  9.04         381          110                  3  3.5   3.5
# 381      325.0  9.11         382          107                  3  3.0   3.5
# 382      330.0  9.45         383          116                  4  5.0   4.5
# 383      312.0  8.78         384          103                  3  3.5   4.0
# 384      333.0  9.66         385          117                  4  5.0   4.0
#
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# your code here

admission_df["decision"] = admission_df["deciding_column"].apply(lambda x: 1 if x > 0.8 else 0)

# %%
admission_df
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR   \
# 0        337.0  9.65           1          118                  4  4.5   4.5
# 1        316.0  8.00           2          104                  3  3.0   3.5
# 2        322.0  8.67           3          110                  3  3.5   2.5
# 3        314.0  8.21           4          103                  2  2.0   3.0
# 4        330.0  9.34           5          115                  5  4.5   3.0
# ..         ...   ...         ...          ...                ...  ...   ...
# 380      324.0  9.04         381          110                  3  3.5   3.5
# 381      325.0  9.11         382          107                  3  3.0   3.5
# 382      330.0  9.45         383          116                  4  5.0   4.5
# 383      312.0  8.78         384          103                  3  3.5   4.0
# 384      333.0  9.66         385          117                  4  5.0   4.0
#
# ...

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here

accepted_applicants = admission_df["decision"].sum()
print(accepted_applicants)
# Out:
# 136

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# your code here

admission_df.columns = admission_df.columns.str.replace(r'[^\w\s]', "").str.replace(" ", "_").str.lower()

admission_df
# Out:
# /var/folders/n7/qn8s75510p5chs7mw2tvcgy80000gp/T/ipykernel_2416/3357197585.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   admission_df.columns = admission_df.columns.str.replace(r'[^\w\s]', "").str.replace(" ", "_").str.lower()
#      gre_score  cgpa  serial_no  toefl_score  university_rating  sop  lor_  \
# 0        337.0  9.65          1          118                  4  4.5   4.5
# 1        316.0  8.00          2          104                  3  3.0   3.5
# 2        322.0  8.67          3          110                  3  3.5   2.5
# 3        314.0  8.21          4          103                  2  2.0   3.0
# 4        330.0  9.34          5          115                  5  4.5   3.0
# ..         ...   ...        ...          ...                ...  ...   ...
# 380      324.0  9.04        381          110                  3  3.5   3.5
# 381      325.0  9.11        382          107                  3  3.0   3.5
# ...

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here

mask = admission_df["university_rating"] >= 4
admission_df.loc[mask, "gre_score"] += 10
bins = [0, 300, 320, 340, float('inf')] 

labels = ["Low", "Medium", "High", "Very High"]
admission_df["adjusted_gre"] = pd.cut(admission_df["gre_score"], bins=bins, labels=labels)

admission_df

#a little lost on this but i google an example and it helped
# Out:
#      gre_score  cgpa  serial_no  toefl_score  university_rating  sop  lor_  \
# 0        367.0  9.65          1          118                  4  4.5   4.5
# 1        316.0  8.00          2          104                  3  3.0   3.5
# 2        322.0  8.67          3          110                  3  3.5   2.5
# 3        314.0  8.21          4          103                  2  2.0   3.0
# 4        360.0  9.34          5          115                  5  4.5   3.0
# ..         ...   ...        ...          ...                ...  ...   ...
# 380      324.0  9.04        381          110                  3  3.5   3.5
# 381      325.0  9.11        382          107                  3  3.0   3.5
# 382      360.0  9.45        383          116                  4  5.0   4.5
# 383      312.0  8.78        384          103                  3  3.5   4.0
# 384      363.0  9.66        385          117                  4  5.0   4.0
#
#      research  chance_of_admit_  cgpa_std     gre_std  lor_std  \
# ...
